# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv('Bikash_zeeman_slower_data.csv')

# %%
df
# Out:
#        Unnamed: 0  Magnetic_Field_Strength (G)  \
# 0               0                    57.732475
# 1               1                    88.755010
# 2               2                    80.061659
# 3               3                    94.725660
# 4               4                    73.433315
# ...           ...                          ...
# 11495         495                    12.837751
# 11496         496                    12.719884
# 11497         497                    71.067639
# 11498         498                    63.314168
# 11499         499                    94.624521
#
#        Magnetic_Field_Direction (rad)  Magnetic_Field_Gradient (G/cm)  \
# 0                            5.148411                       81.912124
# 1                            6.068033                       83.808728
# 2                            5.211639                       76.161547
# 3                            6.235141                       78.330606
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      11500 non-null  int64
#  1   Magnetic_Field_Strength (G)     11500 non-null  float64
#  2   Magnetic_Field_Direction (rad)  11500 non-null  float64
#  3   Magnetic_Field_Gradient (G/cm)  11500 non-null  float64
#  4   Pressure (Torr)                 11500 non-null  float64
#  5   Temperature (K)                 11500 non-null  float64
#  6   Laser_Detuning (GHz)            11500 non-null  float64
#  7   Number_of_Ring_Magnets          11500 non-null  int64
#  8   Radius_of_Ring_Magnets (cm)     11500 non-null  float64
#  9   Slowing_Efficiency_in_percent   11500 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 898.6 KB

# %%
sns.lmplot(x='lowing_Efficiency_in_percent',y='agnetic_Field_Gradient (G/cm)', data = df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-876cbfd4c050> in <module>
# ----> 1 sns.lmplot(x='lowing_Efficiency_in_percent',y='agnetic_Field_Gradient (G/cm)', data = df)
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
# ...
